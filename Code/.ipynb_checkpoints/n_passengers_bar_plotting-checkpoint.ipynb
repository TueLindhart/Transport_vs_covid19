# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Fremkommelighedsanalyse_med_fraktil_og_potentiale_Hast_MarApr.csv",sep=";",
                 header=2,index_col=False,decimal=",")

# %%
df
# Out:
#                     LineDirectionName OperatingDayTypeDisplayName  \
# 0          Herfølge skole - Køge St.                  Hverdag (1)
# 1          Herfølge skole - Køge St.                  Hverdag (1)
# 2          Herfølge skole - Køge St.                  Hverdag (1)
# 3          Herfølge skole - Køge St.                  Hverdag (1)
# 4          Herfølge skole - Køge St.                  Hverdag (1)
# ...                               ...                         ...
# 282166  Ålsgårde St. - Espergærde St.                 Hverdag (1)
# 282167  Ålsgårde St. - Espergærde St.                 Hverdag (1)
# 282168  Ålsgårde St. - Espergærde St.                 Hverdag (1)
# 282169  Ålsgårde St. - Espergærde St.                 Hverdag (1)
# 282170  Ålsgårde St. - Espergærde St.                 Hverdag (1)
#
#        StopPointSectionMunicipalityDisplayName LineDesignation  \
# 0                                         Køge             241
# 1                                         Køge             241
# 2                                         Køge             241
# 3                                         Køge             241
# 4                                         Køge             241
# ...                                        ...             ...
# 282166                               Helsingør             345
# 282167                               Helsingør             345
# 282168                               Helsingør             345
# 282169                               Helsingør             345
# 282170                               Helsingør             345
#
#         StopPointSectionFromNumber                StopPointSectionDisplayName  \
# 0                             5336  Svansbjergvej (5336) - Solvangsvej (5652)
# 1                             5395       Torvebyen (5395) - Fændediget (5396)
# 2                             5396        Fændediget (5396) - Køge St. (8985)
# 3                             5644   Præstebanken (5644) - Nonnebanken (5645)
# 4                             5645     Nonnebanken (5645) - Vestertorp (5647)
# ...                            ...                                        ...
# 282166                       53098       Hellebækvej 5 (53098) - Gurre (3479)
# 282167                       53098       Hellebækvej 5 (53098) - Gurre (3479)
# 282168                       53098       Hellebækvej 5 (53098) - Gurre (3479)
# 282169                       53098       Hellebækvej 5 (53098) - Gurre (3479)
# 282170                       53098       Hellebækvej 5 (53098) - Gurre (3479)
#
#         Hour  PlannedStopPointDistanceMeters  Køretid_observeret__netto1  \
# 0          7                          549.46                       46.93
# 1          7                          408.68                       57.47
# 2          7                          506.31                       62.00
# 3          7                          331.61                       43.40
# 4          7                          403.96                       54.60
# ...      ...                             ...                         ...
# 282166     8                         2420.73                      209.70
# 282167     9                         2420.73                      208.14
# 282168    14                         2420.73                      220.42
# 282169    15                         2420.73                      216.52
# 282170    16                         2420.73                      218.05
#
#         Hastighed_observeret__netto__km_t_  Opholdstid_observeret_ved_stop  \
# 0                                    42.15                           39.73
# 1                                    25.60                            0.00
# 2                                    29.40                            0.00
# 3                                    27.51                            0.00
# 4                                    26.63                           28.47
# ...                                    ...                             ...
# 282166                               41.56                            1.05
# 282167                               41.87                            1.57
# 282168                               39.54                            2.74
# 282169                               40.25                            2.43
# 282170                               39.97                            1.05
#
#         Køretid_observeret__brutto  Hastighed_observeret__brutto__km_t_  \
# 0                            86.67                                22.82
# 1                            57.47                                25.60
# 2                            60.92                                29.92
# 3                            43.40                                27.51
# 4                            83.07                                17.51
# ...                            ...                                  ...
# 282166                      210.75                                41.35
# 282167                      209.71                                41.55
# 282168                      223.16                                39.05
# 282169                      218.95                                39.80
# 282170                      219.10                                39.78
#
#         Fraktil_Netto  Fraktil_Brutto  Observations  Potentiale_Netto1  \
# 0                45.6            45.6            21                0.4
# 1                55.6            55.6            21                1.4
# 2                58.0            58.0            21                4.0
# 3                43.2            43.2            21                0.0
# 4                55.0            55.0            21                0.0
# ...               ...             ...           ...                ...
# 282166          210.2           211.2            21                0.0
# 282167          210.2           211.2            21                0.0
# 282168          210.2           211.2            21                9.8
# 282169          210.2           211.2            21                5.8
# 282170          210.2           211.2            21                7.8
#
#         Potentiale_Brutto
# 0                    40.4
# 1                     1.4
# 2                     2.0
# 3                     0.0
# 4                    28.0
# ...                   ...
# 282166                0.0
# 282167                0.0
# 282168               11.8
# 282169                6.8
# 282170                7.8
#
# [282171 rows x 18 columns]

# %% [markdown]
# # Downloading passenger data

# %%
import os
import pandas as pd
os.getcwd()
# Out:
# '/Users/tuethomsen28/Google Drev/SocialDataVizz/Kode'

# %%
sel_mun = ["Albertslund","Ballerup","Brøndby","Dragør","Frederiksberg","Gentofte","Gladsaxe",
                           "Glostrup","Herlev","Hvidovre","Høje-Taastrup","Hørsholm","Ishøj","København",
                           "Rødovre","Tårnby"]

# %%
path = '/Users/tuethomsen28/Google Drev/SocialDataVizz/Data/' + 'Passagertal_SenesteVersion.csv'

df = pd.read_csv(path,sep=";",
                 thousands=",")

df.shape
# Out:
# (14365, 13)

# %%
df_201902 = df[["Kommune","På_201902","Af_201902"]].dropna()
df_201903 = df[["Kommune","På_201903","Af_201903"]].dropna()
df_202002 = df[["Kommune","På_202002","Af_202002"]].dropna()
df_202003 = df[["Kommune","På_202003","Af_202003"]].dropna()

# %%
passenger_df = df_201902.groupby(["Kommune"]).mean().loc[sel_mun]

passenger_df = passenger_df.join(df_201903.groupby(["Kommune"]).mean().loc[sel_mun],
                                 on="Kommune")
passenger_df = passenger_df.join(df_202002.groupby(["Kommune"]).mean().loc[sel_mun],
                                 on="Kommune")
passenger_df = passenger_df.join(df_202003.groupby(["Kommune"]).mean().loc[sel_mun],
                                 on="Kommune")

# %%
passenger_df
# Out:
#                 På_201902   Af_201902   På_201903   Af_201903   På_202002  \
# Kommune
# Albertslund     20.964286   21.683036   25.084821   25.406250   22.808036
# Ballerup        43.322368   43.322368   44.401316   45.013158   43.306189
# Brøndby         31.015152   31.479798   33.020202   33.994949   30.386935
# Dragør          18.159664   18.672269   17.235294   22.008403   17.181034
# Frederiksberg  142.439024  142.845528  137.872587  143.505792  107.879845
# Gentofte        26.847418   27.774648   28.738208   30.150943   28.289238
# Gladsaxe        57.394137   57.394137   56.837134   55.902280   48.866295
# Glostrup        75.394366   75.788732   77.852113   75.654930   73.489655
# Herlev          56.010695   57.641711   55.037433   56.085561   55.892045
# Hvidovre        55.881818   57.927273   59.790909   60.550000   56.862559
# Høje-Taastrup   42.344322   42.003663   45.476190   45.457875   28.503546
# Hørsholm        19.249057   21.200000   21.622642   22.724528   18.343396
# Ishøj           29.500000   31.793103   34.254386   33.500000   28.245614
# København      168.391092  163.327639  175.313595  169.588520  142.165633
# Rødovre         49.420601   50.085837   49.225532   51.476596   47.226667
# Tårnby          38.166667   40.151515   41.560606   39.843434   36.535000
#
#                 Af_202002  På_202003  Af_202003
# Kommune
# Albertslund     22.477679  11.183036  11.799107
# Ballerup        43.218241  25.032573  25.723127
# Brøndby         30.507538  19.673367  19.562814
# Dragør          17.250000  10.793103  11.198276
# Frederiksberg  110.767442  58.980620  60.480620
# Gentofte        28.800448  16.020362  16.427602
# Gladsaxe        49.058496  29.651811  30.740947
# Glostrup        76.151724  44.475862  45.531034
# Herlev          58.681818  33.267045  34.482955
# Hvidovre        54.805687  34.308057  34.232227
# Høje-Taastrup   27.765957  16.127660  15.978723
# Hørsholm        20.154717  11.452830  11.958491
# Ishøj           29.473684  18.657895  19.649123
# København      141.650124  77.544272  77.753560
# Rødovre         49.395556  29.244444  29.768889
# Tårnby          37.855000  23.330000  24.360000

# %% [markdown]
# # Create plot

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, FactorRange, Legend, HoverTool
from bokeh.transform import dodge
import bokeh.palettes
import urllib.request as urllib2
output_notebook()
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#Creating format fitting for bokeh
source = ColumnDataSource(passenger_df)

#Creating a list for the x-axis on the bar-chart. 
x_range = [str(h) for h in source.data['Kommune']]

#Generating 14 colors for the different focus crimes  
colors = bokeh.palettes.Category20[len(passenger_df)]

bar ={} # to store vbars

# %%
#Creating figure frame with title, x -and y labels and disabling toolbar. 
p = figure(x_range=FactorRange(factors=x_range),
           title='Barchart of average number of onboarding passengers',
           x_axis_label='Hour of day',
           y_axis_label='Frequency',
           plot_width=950,plot_height=500,
           toolbar_location=None)

#Generating barcharts to p 
for indx,i in enumerate(sel_mun):
    bar[i] = p.vbar(x=dodge('Kommune',0.5),  top=i, source= source, width=0.8, 
                 fill_alpha=0.5,line_color=None,
                 color=colors[indx],visible=False)

# %%
items = [(i,[bar[i]]) for i in sel_mun] #Creating list of tuples with focus crime name and belonging bar chart. 
legend = Legend(items=items,location=(0,90)) # Creating legends with 'items'
p.add_layout(legend,'left') # Adding legends to ´p´ and setting location.

# %%
p.legend.click_policy="hide"
p.legend.title = 'To see a crime click on the crime below'

show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Albertslund" [renderer: GlyphRenderer(id=1222, glyph=VBar(id='1220', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Ballerup" [renderer: GlyphRenderer(id=1228, glyph=VBar(id='1226', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Brøndby" [renderer: GlyphRenderer(id=1234, glyph=VBar(id='1232', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Dragør" [renderer: GlyphRenderer(id=1240, glyph=VBar(id='1238', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Frederiksberg" [renderer: GlyphRenderer(id=1246, glyph=VBar(id='1244', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Gentofte" [renderer: GlyphRenderer(id=1252, glyph=VBar(id='1250', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Gladsaxe" [renderer: GlyphRenderer(id=1258, glyph=VBar(id='1256', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Glostrup" [renderer: GlyphRenderer(id=1264, glyph=VBar(id='1262', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Herlev" [renderer: GlyphRenderer(id=1270, glyph=VBar(id='1268', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Hvidovre" [renderer: GlyphRenderer(id=1276, glyph=VBar(id='1274', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Høje-Taastrup" [renderer: GlyphRenderer(id=1282, glyph=VBar(id='1280', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Hørsholm" [renderer: GlyphRenderer(id=1288, glyph=VBar(id='1286', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Ishøj" [renderer: GlyphRenderer(id=1294, glyph=VBar(id='1292', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "København" [renderer: GlyphRenderer(id=1300, glyph=VBar(id='1298', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Rødovre" [renderer: GlyphRenderer(id=1306, glyph=VBar(id='1304', ...), ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "top" value "Tårnby" [renderer: GlyphRenderer(id=1312, glyph=VBar(id='1310', ...), ...)]
#   <div class="bk-root" id="17f8270b-38eb-47fe-b763-04ab3b58e966" data-root-id="1188"></div>
